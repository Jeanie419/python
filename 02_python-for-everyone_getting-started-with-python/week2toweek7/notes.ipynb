# %% [markdown]
# # Installing Python and Writing A Program
# - 演示如何下载python3，输出简单的程序，现阶段没有电脑的可以使用coursera自带的python playground
# - 正确使用Windows的command的指令，以及Mac的terminal
# - 不同系统的截图操作

# %% [markdown]
# # introduction
# - if,while循环
# - 计算一段文字的单词出现的次数
