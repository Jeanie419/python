# %% [markdown]
# # Why Program
#
#  我们的生活中出现越来越多的科技，成为科技的创造者 而不仅仅只是科技的消费者
#
#  我们人类可以在感受到错误的同时修正它们 因为我们能理解这些错误，但是计算机不一样 它们不是这样工作的 即便语音识别技术得到了发展 软件可以学习如何筛选错误 但是这样的代码还是很难编写 计算机无法理解如何筛选错误 但如果有足够的指令 你可以让它们筛选错误
#
#  text analysis, is one of those things that computers are really good at and we humans are really bad at. So it's really great to delegate this problem to a computer, if you know the language of the computer and you can talk to the computer

# %% [markdown]
# # Hardware Overview
#
# 计算机由运算器、控制器、存储器、输入设备和输出设备等五个逻辑部件组成

# %% [markdown]
# # Python as a Language
#
# 20多年前吉多·范·罗斯姆发明了python 语言
#
# 语法错误并不意味着Python认为你很糟糕。 这也不是对你作为程序员的能力的一个评判标准， 这更不是对你成为程序员的潜力的评判标准。 语法错误意味着Python不能理解。你可以学习Python的语言，但Python无法学习你的语言.不要因为重复的语法报错而对自己感觉怀疑。
